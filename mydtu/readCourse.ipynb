# %% [markdown]
# ## Đọc file lịch thi

# %% [markdown]
# ### Để lấy ra mã môn, tên môn, hình thức thi, khoa chủ trì

# %%
import pandas as pd

# %%
filePath = 'D://LichThiKTHPHK12NamHoc2023-2024Tuan41-43(chinhthuc).xlsx'
df = pd.read_excel(filePath, keep_default_na=False)

# %% [markdown]
# `Bắt đầu xử lý để tạo ra một dataframe tiêu chuẩn`

# %%
df.head()
# Out:
#                               TRƯỜNG ĐẠI HỌC DUY TÂN Unnamed: 1  \
# 0                                      PHÒNG ĐÀO TẠO
# 1
# 2                                                STT        Thứ
# 3  Lịch thi lại học kỳ 1 (2023-2024) - Danh sách ...
# 4                                                  1          3
#
#             Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0
# 1
# 2            Ngày thi   Giờ \nthi   Mã ngành      Mã số     Mã môn
# 3
# 4  2024-05-28 00:00:00      09h30      IS-CS        412  IS-CS 412
#
#                                    NĂM HỌC 2023-2024  \
# 0  LỊCH THI KTHP HỌC KỲ 1, 2 - TUẦN 41--43 (C...
# 1  (TT KHẢO THÍ PHỐI HỢP VỚI CÁC ĐƠN VỊ LIÊN...
# 2                                            Môn thi
# 3
# 4                    Introduction to Cloud Computing
#
#                             Unnamed: 8       Unnamed: 9 Unnamed: 10  \
# 0
# 1
# 2                      Hình thức thi         Khối thi   Lần\n thi
# 3
# ...

# %%
df = df.iloc[2:].reset_index(drop=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 580 entries, 0 to 579
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   TRƯỜNG ĐẠI HỌC DUY TÂN  580 non-null    object
#  1   Unnamed: 1              580 non-null    object
#  2   Unnamed: 2              580 non-null    object
#  3   Unnamed: 3              580 non-null    object
#  4   Unnamed: 4              580 non-null    object
#  5   Unnamed: 5              580 non-null    object
#  6   Unnamed: 6              580 non-null    object
#  7    NĂM HỌC 2023-2024      580 non-null    object
#  8   Unnamed: 8              580 non-null    object
#  9   Unnamed: 9              580 non-null    object
#  10  Unnamed: 10             580 non-null    object
#  11  Unnamed: 11             580 non-null    object
#  12  Unnamed: 12             580 non-null    object
#  13  Unnamed: 13             580 non-null    object
# ...

# %%
df.columns = df.iloc[0]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 580 entries, 0 to 579
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   STT              580 non-null    object
#  1   Thứ              580 non-null    object
#  2   Ngày thi         580 non-null    object
#  3   Giờ
# thi         580 non-null    object
#  4   Mã ngành         580 non-null    object
#  5   Mã số            580 non-null    object
#  6   Mã môn           580 non-null    object
#  7   Môn thi          580 non-null    object
#  8   Hình thức thi  580 non-null    object
#  9   Khối thi         580 non-null    object
#  10  Lần
#  thi         580 non-null    object
#  11  SL
# Phòng        580 non-null    object
#  12  SL SV            580 non-null    object
#  13  Phòng thi        580 non-null    object
#  14  Địa điểm         580 non-null    object
#  15  Khoa chủ trì     580 non-null    object
# ...

# %%
df = df.iloc[1:].reset_index(drop=True)
df.head()
# Out:
# 0                                                STT Thứ            Ngày thi   \
# 0  Lịch thi lại học kỳ 1 (2023-2024) - Danh sách ...
# 1                                                  1   3  2024-05-28 00:00:00
# 2                      Lịch thi học kỳ 2 (2023-2024)
# 3                                                  1   3  2024-05-28 00:00:00
# 4                                                  2   3  2024-05-28 00:00:00
#
# 0 Giờ \nthi Mã ngành Mã số     Mã môn                          Môn thi  \
# 0
# 1     09h30    IS-CS   412  IS-CS 412  Introduction to Cloud Computing
# 2
# 3     07h30      MKT   364    MKT 364            Quảng Cáo & Chiêu Thị
# 4     07h30      AET   497    AET 497                       Đồ án CDIO
#
# 0                      Hình thức thi               Khối thi Lần\n thi  \
# 0
# 1  Trắc nghiệm + Tự luận, Phòng LT        IS-CS 412 (AIS)         1
# 2
# 3                 Tự luận, Phòng LT  MKT 364 (J-L-R-T-V-X)         1
# ...

# %%
df = df.drop([0,2])
df.head()
# Out:
# 0 STT Thứ            Ngày thi  Giờ \nthi Mã ngành Mã số     Mã môn  \
# 1   1   3  2024-05-28 00:00:00     09h30    IS-CS   412  IS-CS 412
# 3   1   3  2024-05-28 00:00:00     07h30      MKT   364    MKT 364
# 4   2   3  2024-05-28 00:00:00     07h30      AET   497    AET 497
# 5   3   3  2024-05-28 00:00:00     07h30      MTH   103    MTH 103
# 6   4   3  2024-05-28 00:00:00     07h30      MIB   251    MIB 251
#
# 0                          Môn thi                      Hình thức thi  \
# 1  Introduction to Cloud Computing  Trắc nghiệm + Tự luận, Phòng LT
# 3            Quảng Cáo & Chiêu Thị                 Tự luận, Phòng LT
# 4                       Đồ án CDIO                    Vấn đáp, Phòng LT
# 5                  Toán Cao Cấp A1  Trắc nghiệm + Tự luận, Phòng LT
# 6              Căn Bản Vi Sinh Học  Trắc nghiệm + Tự luận, Phòng LT
#
# 0                     Khối thi Lần\n thi SL \nPhòng SL SV  \
# 1              IS-CS 412 (AIS)         1          1     3
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 577 entries, 1 to 578
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   STT              577 non-null    object
#  1   Thứ              577 non-null    object
#  2   Ngày thi         577 non-null    object
#  3   Giờ
# thi         577 non-null    object
#  4   Mã ngành         577 non-null    object
#  5   Mã số            577 non-null    object
#  6   Mã môn           577 non-null    object
#  7   Môn thi          577 non-null    object
#  8   Hình thức thi  577 non-null    object
#  9   Khối thi         577 non-null    object
#  10  Lần
#  thi         577 non-null    object
#  11  SL
# Phòng        577 non-null    object
#  12  SL SV            577 non-null    object
#  13  Phòng thi        577 non-null    object
#  14  Địa điểm         577 non-null    object
#  15  Khoa chủ trì     577 non-null    object
# ...

# %%
df1 = df.loc[:,['Mã ngành','Mã số','Mã môn','Môn thi','Hình thức thi','SL SV','Khoa chủ trì']]
df1.head()
# Out:
# 0 Mã ngành Mã số     Mã môn                          Môn thi  \
# 1    IS-CS   412  IS-CS 412  Introduction to Cloud Computing
# 3      MKT   364    MKT 364            Quảng Cáo & Chiêu Thị
# 4      AET   497    AET 497                       Đồ án CDIO
# 5      MTH   103    MTH 103                  Toán Cao Cấp A1
# 6      MIB   251    MIB 251              Căn Bản Vi Sinh Học
#
# 0                      Hình thức thi SL SV Khoa chủ trì
# 1  Trắc nghiệm + Tự luận, Phòng LT     3  Trường ĐTQT
# 3                 Tự luận, Phòng LT   722         QTKD
# 4                    Vấn đáp, Phòng LT    61       Cơ Khí
# 5  Trắc nghiệm + Tự luận, Phòng LT   853    MT & KHTN
# 6  Trắc nghiệm + Tự luận, Phòng LT   173            Y

# %%
x = df1.shape[0]
x
# Out:
# 577

# %%
df1.dropna(inplace=True)
df1.shape[0]
# Out:
# 577

# %%
df1.to_excel('subjectTitle.xlsx', index=False)

# %%
df1.to_csv('subjectTile.csv', index=False)
